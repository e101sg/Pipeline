# %%
# !pip install Google-Colab-Transfer

# %%
import colab_transfer
colab_transfer.mount_google_drive()

# %%
google_drive_is_mounted = colab_transfer.is_google_drive_mounted()
print(google_drive_is_mounted)
# Out:
# True

# %%
#from google.colab import drive
#drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.chdir('/content/drive/MyDrive/')
print("Current directory:", os.getcwd())
# Out:
# Current directory: /content/drive/MyDrive

# %%
# !pwd
# Out:
# /content/drive/MyDrive

# %%
#remove the Pipeline folder if it is already there in /MyDrive (Google Drive)
# !rm -r Pipeline

# %%
# Clone the Pipeline Github Repo (public) ---> /content/drive/MyDrive
# !git clone https://github.com/e101sg/Pipeline.git
# Out:
# Cloning into 'Pipeline'...
# remote: Enumerating objects: 66, done.
# remote: Counting objects: 100% (66/66), done.
# remote: Compressing objects: 100% (61/61), done.
# remote: Total 66 (delta 21), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (66/66), 11.08 MiB | 13.00 MiB/s, done.
# Resolving deltas: 100% (21/21), done.
